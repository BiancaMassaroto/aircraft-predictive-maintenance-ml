# %% [markdown]
# EDA
#
# - Tendencia de degradacao ao longo do tempo
# - correlacao entre sensores
# - feature importance inicial
# - distribuicao de falhas

# %% [markdown]
# Train 001

# %%
# Importar e manipular dados
# Criar funcoes para usar em cada arquivo de treino e teste
import os
import pandas as pd

train_001 = "/Users/biancamassaroto/Documents/coding/ml_projects/aircraft_predictive_maintenance_ml/data/modified/test_FD001_processed.csv"
df_train_001 = pd.read_csv(train_001)
df_train_001
# Out:
#        unit_id  time_cycles  op_setting_1  op_setting_2  op_setting_3  \
# 0            1            1        0.0023        0.0003         100.0
# 1            1            2       -0.0027       -0.0003         100.0
# 2            1            3        0.0003        0.0001         100.0
# 3            1            4        0.0042        0.0000         100.0
# 4            1            5        0.0014        0.0000         100.0
# ...        ...          ...           ...           ...           ...
# 13091      100          194        0.0049        0.0000         100.0
# 13092      100          195       -0.0011       -0.0001         100.0
# 13093      100          196       -0.0006       -0.0003         100.0
# 13094      100          197       -0.0038        0.0001         100.0
# 13095      100          198        0.0013        0.0003         100.0
#
#        sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  \
# ...

# %% [markdown]
# Tendencia de degradacao ao longo do tempo
#
# - regressão linear
# - ajustar uma reta aos dados e observar a inclinação pode indicar se há uma tendência de aumento ou diminuição de um parâmetro ao longo do tempo.
