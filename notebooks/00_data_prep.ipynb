# %%
import os
import pandas as pd

archives = "/Users/biancamassaroto/Documents/coding/ml_projects/aircraft_predictive_maintenance_ml/data/raw"

for file in archives:
    if "train" or "test" in os.path:
